# %%
a = [i for i in range(1,6)]
a[::-3]
# Out:
# [5, 2]

# %%
a[2] = [1,2]
a
# Out:
# [1, 2, [1, 2], 4, 5]

# %%
del(a[2])

# %%
a
# Out:
# [1, 2, 4, 5]

# %%
a.remove(4)

# %%
a
# Out:
# [1, 2, 5]

# %%
a.remove(6) #delete based on element value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a.remove(6)
#
# ValueError: list.remove(x): x not in list

# %%
del(a[6]) #del based on index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del(a[6])
#
# IndexError: list assignment index out of range
